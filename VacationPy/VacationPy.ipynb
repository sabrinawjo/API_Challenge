# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Keep an eye on your API usage. Use https://developers.google.com/maps/reporting/gmp-reporting as reference for how to monitor your usage and billing.
#
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os

# Import API key
from api_keys import g_key

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
output_data_file = "../output_data/cities.csv"
df = pd.read_csv(output_data_file)
df
# Out:
#      City_ID         City  Cloudiness Country        Date  Humidity    Lat  \
# 0          0    ostrovnoy           2      RU  1558378754        72  68.05
# 1          1    mahebourg          75      MU  1558378503        74 -20.41
# 2          2      qaanaaq          25      GL  1558378755        73  77.48
# 3          3       zhuhai           0      CN  1558378755        39  40.71
# 4          4    cape town          20      ZA  1558378755        76 -33.93
# ..       ...          ...         ...     ...         ...       ...    ...
# 543      543       yabrud           0      SY  1558378840        32  33.97
# 544      544      paraiso           5      MX  1558378898         4  24.01
# 545      545      veraval           0      FR  1558378898        62  49.65
# 546      546  novyy urgal         100      RU  1558378899        93  51.07
# 547      547      tongren           4      CN  1558378899        64  27.72
#
#         Lng  Max Temp  Wind Speed
# 0     39.51     37.50        7.16
# 1     57.70     78.80       11.41
# 2    -69.36     22.20        2.37
# 3    112.04     44.60        4.47
# 4     18.42     55.99        8.05
# ..      ...       ...         ...
# 543   36.66     80.60        8.05
# 544 -104.61     84.20       16.11
# 545    0.71     61.00        8.05
# 546  132.56     49.74        2.68
# 547  109.18     55.86        2.84
#
# [548 rows x 10 columns]

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
gmaps.configure(api_key=g_key)
locations = df[["Lat", "Lng"]].astype(float)
humidity = df["Humidity"].astype(float)

# %%
fig = gmaps.figure()

heat_layer = gmaps.heatmap_layer(locations, weights=humidity, 
                                 dissipating=False, max_intensity=100,
                                 point_radius = 1)

fig.add_layer(heat_layer)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
destination_df=df.loc[((df["Cloudiness"] == 0) & (df["Humidity"]>50))]
destination_df["City"]
# Out:
# 6              flinders
# 11               castro
# 13            saskylakh
# 31              qingdao
# 33                arman
# 37              varhaug
# 57              kolyvan
# 70         ponta do sol
# 84              emerald
# 88             cidreira
# 112          bredasdorp
# 114              koumac
# 125     arraial do cabo
# 129               paita
# 138           morondava
# 139               vaini
# 141            sanchazi
# 168            straumen
# 179          chokurdakh
# 191          naryan-mar
# 192        port hedland
# 214           mount isa
# 219           beisfjord
# 220          ust-tsilma
# 226         saint-denis
# 244               pasni
# 248               ancud
# 251       leningradskiy
# 252             kajaani
# 262              umtata
# 271           coihaique
# 297               mogok
# 298             mikkeli
# 309           upernavik
# 316              gunjur
# 359             sorland
# 365           ulladulla
# 391              namibe
# 404              manama
# 412                 diu
# 422             susuman
# 427            hastings
# 433              svodin
# 438             waipawa
# 446         henties bay
# 477           bundaberg
# 508              noumea
# 527            tomatlan
# 538    la seyne-sur-mer
# 545             veraval
# Name: City, dtype: object

# %%
destination_df['name'] = ""
destination_df
# Out:
# <ipython-input-66-2e36a852e619>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   destination_df['name'] = ""
#      City_ID              City  Cloudiness Country        Date  Humidity  \
# 6          6          flinders           0      AU  1558378755        62
# 11        11            castro           0      CL  1558378756        70
# 13        13         saskylakh           0      RU  1558378757        91
# 31        31           qingdao           0      CN  1558378760        54
# 33        33             arman           0      RU  1558378760        64
# 37        37           varhaug           0      NO  1558378761        63
# 57        57           kolyvan           0      RU  1558378764        87
# 70        70      ponta do sol           0      BR  1558378767        57
# 84        84           emerald           0      AU  1558378770        82
# 88        88          cidreira           0      BR  1558378770        66
# 112      112        bredasdorp           0      ZA  1558378775        62
# 114      114            koumac           0      NC  1558378775        68
# 125      125   arraial do cabo           0      BR  1558378491        78
# 129      129             paita           0      PE  1558378778       290
# 138      138         morondava           0      MG  1558378780        69
# 139      139             vaini           0      IN  1558378780        88
# 141      141          sanchazi           0      CN  1558378781        82
# 168      168          straumen           0      NO  1558378786        52
# 179      179        chokurdakh           0      RU  1558378788        89
# 191      191        naryan-mar           0      RU  1558378791        90
# 192      192      port hedland           0      AU  1558378791        51
# 214      214         mount isa           0      AU  1558378794        56
# 219      219         beisfjord           0      NO  1558378796        51
# 220      220        ust-tsilma           0      RU  1558378796        58
# 226      226       saint-denis           0      FR  1558378797        67
# 244      244             pasni           0      PK  1558378823        52
# 248      248             ancud           0      CL  1558378825        70
# 251      251     leningradskiy           0      RU  1558378827        80
# 252      252           kajaani           0      FI  1558378827        62
# 262      262            umtata           0      ZA  1558378835        51
# 271      271         coihaique           0      CL  1558378837        59
# 297      297             mogok           0      MM  1558378844        51
# 298      298           mikkeli           0      FI  1558378844        59
# 309      309         upernavik           0      GL  1558378846        85
# 316      316            gunjur           0      GM  1558378848        61
# 359      359           sorland           0      NO  1558378858        71
# 365      365         ulladulla           0      AU  1558378859        62
# 391      391            namibe           0      AO  1558378870        74
# 404      404            manama           0      AE  1558378872        52
# 412      412               diu           0      IN  1558378873        75
# 422      422           susuman           0      RU  1558378875        75
# 427      427          hastings           0      NZ  1558378877        93
# 433      433            svodin           0      SK  1558378878        72
# 438      438           waipawa           0      NZ  1558378879        93
# 446      446       henties bay           0     NaN  1558378880        91
# 477      477         bundaberg           0      AU  1558378886        93
# 508      508            noumea           0      NC  1558378811        77
# 527      527          tomatlan           0      MX  1558378894        59
# 538      538  la seyne-sur-mer           0      FR  1558378897        72
# 545      545           veraval           0      FR  1558378898        62
#
#        Lat     Lng  Max Temp  Wind Speed name
# 6   -34.58  150.85     60.01       11.41
# 11  -42.48  -73.76     48.20        9.17
# 13   71.97  114.09      4.92        2.26
# 31   36.09  120.35     59.00        2.24
# 33   59.70  150.17     31.56        5.30
# 37   58.61    5.65     64.99        8.05
# 57   55.31   82.74     48.20        4.47
# 70  -20.63  -46.00     73.68        5.32
# 84  -23.53  148.16     60.80        6.93
# 88  -30.17  -50.22     76.56        5.50
# 112 -34.53   20.04     55.00        8.05
# 114 -20.56  164.28     74.40       12.86
# 125 -22.97  -42.02     84.20        4.70
# 129  -5.09  -81.11     62.60       17.22
# 138 -20.30   44.28     79.08        9.06
# 139  15.34   74.49     78.90        1.59
# 141  30.43  103.62     64.40        2.24
# 168  63.87   11.30     68.00        9.17
# 179  70.62  147.90      7.08        5.99
# 191  67.67   53.09     27.24        8.19
# 192 -20.31  118.58     62.60        6.93
# 214 -20.73  139.49     68.00        6.93
# 219  68.38   17.60     60.80       11.41
# 220  65.44   52.15     35.88        6.11
# 226  48.94    2.36     64.40       10.29
# 244  25.26   63.48     86.82        9.17
# 248 -41.87  -73.83     48.20        9.17
# 251  69.38  178.42     22.20        6.38
# 252  64.22   27.73     59.00        6.93
# 262 -31.59   28.78     60.80       17.22
# 271 -45.58  -72.07     46.40        4.70
# 297  22.92   96.51     72.24        2.77
# 298  61.69   27.27     62.60        6.93
# 309  72.79  -56.15     29.22       11.59
# 316  13.18  -16.76     80.60        9.17
# 359  67.67   12.69     53.60        5.82
# 365 -35.36  150.48     60.01       11.41
# 391 -15.19   12.15     71.70       17.40
# 404  25.33   56.02     91.40       14.99
# 412  20.71   70.98     83.04       12.82
# 422  62.78  148.15     22.38        3.15
# 427 -39.64  176.84     42.18        2.64
# 433  47.91   18.50     63.00        6.93
# 438 -39.94  176.59     33.01        2.64
# 446 -22.12   14.28     59.00        5.99
# 477 -24.87  152.35     61.00        6.93
# 508 -22.28  166.46     64.40        2.24
# 527  19.93 -105.25     84.66        7.90
# 538  43.10    5.88     69.01        2.24
# 545  49.65    0.71     61.00        8.05

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
params = {
    "rankby": "distance",
    "type": "lodging",
    "key": g_key,
}

for index, row in destination_df.iterrows():

    # get restaurant type from df
    lat = row['Lat']
    lng = row['Lng']

    # add keyword to params dict
    params['location'] = f"{lat},{lng}"

    # assemble url and make API request
    response = requests.get(base_url, params=params).json()
    
    # extract results
    results = response['results']
    
    try:
        print(f"Hotel Name is {results[0]['name']}.")
        destination_df.loc[index, 'name'] = results[0]['name']
        results[0]['name'] = 'Hotel Name'
        
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")
        
    print("------------")
# Out:
# Hotel Name is Shellharbour Resort & Conference Centre.
# ------------
# Hotel Name is Hospedaje El Molo.
# ------------
# C:\Users\jingo\anaconda3\lib\site-packages\pandas\core\indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)
# Missing field/result... skipping.
# ------------
# Hotel Name is 7天酒店.
# ------------
# Missing field/result... skipping.
# ------------
# Hotel Name is Madalina.
# ------------
# Missing field/result... skipping.
# ------------
# Hotel Name is RANCHINHO DO PEDRO CAPITÓLIO.
# ------------
# Hotel Name is Route 66 Motor Inn.
# ------------
# Hotel Name is Vitrine Campeira.
# ------------
# Hotel Name is The Coach House.
# ------------
# Hotel Name is Chez Pascal et Claudia 2.
# ------------
# Hotel Name is Kitnet Aluguel Econômico.
# ------------
# Hotel Name is Hostal A. Paradise.
# ------------
# Hotel Name is Lot D 24 bis Andakabe.
# ------------
# Hotel Name is Dandeli Dreams Jungle Resort.
# ------------
# Hotel Name is Yingbin Hotel.
# ------------
# Hotel Name is Strømnes - oldefars gjestehus.
# ------------
# Missing field/result... skipping.
# ------------
# Hotel Name is Hostel Agat.
# ------------
# Hotel Name is Poshly Port Hedland.
# ------------
# Hotel Name is Mt Isa City Motel.
# ------------
# Hotel Name is Øra Vel.
# ------------
# Hotel Name is U Praskov'i.
# ------------
# Hotel Name is Rosa Parks pension de famille.
# ------------
# Hotel Name is PHE Rest House.
# ------------
# Hotel Name is Cabaña Costa Brava.
# ------------
# Missing field/result... skipping.
# ------------
# Hotel Name is Kauppakatu Apartment.
# ------------
# Hotel Name is 59 On Wesley BnB & Self Catering Accomodation.
# ------------
# Hotel Name is Carlos Campos Lastra.
# ------------
# Hotel Name is Pyae Phyo Kyaw Guest House - Burmese Only.
# ------------
# Hotel Name is Heti Koti Oy.
# ------------
# Hotel Name is Gina's Guesthouse - Upernavik.
# ------------
# Hotel Name is Explorers home.
# ------------
# Hotel Name is Sjybrygga fiskecamp.
# ------------
# Hotel Name is Holiday Haven Ulladulla.
# ------------
# Hotel Name is Parque campismo do Namibe.
# ------------
# Hotel Name is محمد بلال عبدالله البلوشي.
# ------------
# Hotel Name is Hotel Hemal Garden.
# ------------
# Hotel Name is Ao "Susumanzoloto".
# ------------
# Hotel Name is BELLERBY LANE.
# ------------
# Hotel Name is Debrecen Accommodations.
# ------------
# Hotel Name is T A Commercial Hotel.
# ------------
# Hotel Name is Huis henties.
# ------------
# Hotel Name is Bunk Inn Hostel.
# ------------
# Hotel Name is Le Faré Moana.
# ------------
# Hotel Name is Norma franco.
# ------------
# Hotel Name is Immeuble d'habitation.
# ------------
# Hotel Name is Domicile.
# ------------

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in destination_df.iterrows()]
locations = destination_df[["Lat", "Lng"]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-68-335dff406e80> in <module>
#      11 # Store the DataFrame Row
#      12 # NOTE: be sure to update with your DataFrame name
# ---> 13 hotel_info = [info_box_template.format(**row) for index, row in destination_df.iterrows()]
#      14 locations = destination_df[["Lat", "Lng"]]
#
# <ipython-input-68-335dff406e80> in <listcomp>(.0)
#      11 # Store the DataFrame Row
#      12 # NOTE: be sure to update with your DataFrame name
# ---> 13 hotel_info = [info_box_template.format(**row) for index, row in destination_df.iterrows()]
#      14 locations = destination_df[["Lat", "Lng"]]
#
# KeyError: 'Hotel Name'

# %%
# Add marker layer ontop of heat map


# Display figure
